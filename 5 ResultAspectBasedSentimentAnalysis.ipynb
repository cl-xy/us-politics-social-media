# %%
import numpy as np # numerical computation
import pandas as pd # # data processing/manipulation
import matplotlib.pyplot as plt # basic data visualization
# import seaborn as sns # nicer data visualization
import time

# %%
#read CSV data from aspect based sentiment analysis
covid_tweets_df = pd.read_csv("covid_tweets_absa.csv", lineterminator='\n')
fraud_tweets_df = pd.read_csv("fraud_tweets_absa.csv", lineterminator='\n')

# %%
pd.options.display.max_colwidth = 1000

# %% [markdown]
# ### Covid Aspect

# %%
covid_tweets_df.head(10)[['clean_tweet_nltk','covid_negative', 'covid_neutral', 'covid_positive']]
# Out:
#                                                                                                                                                                                                                                               clean_tweet_nltk  \
# 0                                                                                                                                                                                                     use honor refuse covid test enter studio hell away biden
# 1                                                                                                                  shock remake unoriginality hollywood day chrisfarley blacksheep bidenharris joebiden joewillleadus vote bidensunitingus bidenwillcrushcovid
# ...

# %% [markdown]
# ### Fraud Aspect

# %%
fraud_tweets_df.head(10)[['clean_tweet_nltk','covid_negative', 'covid_neutral', 'covid_positive']]
# Out:
#                                                                                                                                                                                                                                               clean_tweet_nltk  \
# 0                                                                                                                                                                                                     use honor refuse covid test enter studio hell away biden
# 1                                                                                                                  shock remake unoriginality hollywood day chrisfarley blacksheep bidenharris joebiden joewillleadus vote bidensunitingus bidenwillcrushcovid
# ...
